# %% [markdown]
# # Ex1 - Getting and knowing your Data

# %% [markdown]
# ### Step 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ###  Step 2. Download the dataset to your computer and unzip it.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 3. Use the tsv file and assign it to a dataframe called food

# %%
food = pd.read_csv('C:\\Users\\li-370\\Downloads\\en.openfoodfacts.org.products.tsv', sep='\t')
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ### Step 4. See the first 5 entries

# %%
food.head()
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3      1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...                         NaN
# 1          NaN      NaN  ...                         NaN
# 2          NaN      NaN  ...                         NaN
# 3          NaN      NaN  ...                         NaN
# 4          NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 0                     NaN                 NaN                 NaN
# 1                    14.0                 NaN                 NaN
# 2                     0.0                 NaN                 NaN
# 3                    12.0                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
# [5 rows x 163 columns]

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
food.shape #will give you both (observations/rows, columns)
# Out:
# (356027, 163)

# %%
food.shape[0] #will give you only the observations/rows number
# Out:
# 356027

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
print(food.shape) #will give you both (observations/rows, columns)
print(food.shape[1]) #will give you only the columns number

#OR

food.info() #Columns: 163 entries
# Out:
# (356027, 163)
# 163
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356027 entries, 0 to 356026
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(107), object(56)
# memory usage: 442.8+ MB

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %% [markdown]
# ### Step 8. What is the name of 105th column?

# %%
food.columns[104]
# Out:
# '-glucose_100g'

# %% [markdown]
# ### Step 9. What is the type of the observations of the 105th column?

# %%
food.dtypes['-glucose_100g']
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 10. How is the dataset indexed?

# %%
food.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %% [markdown]
# ### Step 11. What is the product name of the 19th observation?

# %%
food.values[18][7]
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %%
# %timeit food()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-a45c2bd57c59> in <module>
# ----> 1 get_ipython().run_line_magic('timeit', 'food()')
#
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2312                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2313             with self.builtin_trap:
# -> 2314                 result = fn(*args, **kwargs)
#    2315             return result
#    2316
#
# <C:\Anaconda3\lib\site-packages\decorator.py:decorator-gen-61> in timeit(self, line, cell, local_ns)
#
# C:\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# C:\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, line, cell, local_ns)
#    1156             for index in range(0, 10):
#    1157                 number = 10 ** index
# -> 1158                 time_number = timer.timeit(number)
#    1159                 if time_number >= 0.2:
#    1160                     break
#
# C:\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in timeit(self, number)
#     167         gc.disable()
#     168         try:
# --> 169             timing = self.inner(it, self.timer)
#     170         finally:
#     171             if gcold:
#
# <magic-timeit> in inner(_it, _timer)
#
# TypeError: 'DataFrame' object is not callable

# %%
# %timeit food
# Out:
# 66.6 ns ± 11.7 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %time food
# Out:
# Wall time: 0 ns
#                  code                                                url  \
# 0                3087  http://world-en.openfoodfacts.org/product/0000...
# 1                4530  http://world-en.openfoodfacts.org/product/0000...
# 2                4559  http://world-en.openfoodfacts.org/product/0000...
# 3               16087  http://world-en.openfoodfacts.org/product/0000...
# 4               16094  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...
# 356023  9970229501521  http://world-en.openfoodfacts.org/product/9970...
# 356024  9977471758307  http://world-en.openfoodfacts.org/product/9977...
# 356025  9980282863788  http://world-en.openfoodfacts.org/product/9980...
# 356026   999990026839  http://world-en.openfoodfacts.org/product/9999...
#
#                            creator   created_t      created_datetime  \
# 0       openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1                  usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2                  usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3                  usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4                  usda-ndb-import  1489055653  2017-03-09T10:34:13Z
# ...                            ...         ...                   ...
# 356022             usda-ndb-import  1489059076  2017-03-09T11:31:16Z
# 356023                      tomato  1422099377  2015-01-24T11:36:17Z
# 356024  openfoodfacts-contributors  1497018549  2017-06-09T14:29:09Z
# 356025  openfoodfacts-contributors  1492340089  2017-04-16T10:54:49Z
# 356026             usda-ndb-import  1489072709  2017-03-09T15:18:29Z
#
#        last_modified_t last_modified_datetime  \
# 0           1474103893   2016-09-17T09:18:13Z
# 1           1489069957   2017-03-09T14:32:37Z
# 2           1489069957   2017-03-09T14:32:37Z
# 3           1489055731   2017-03-09T10:35:31Z
# 4           1489055653   2017-03-09T10:34:13Z
# ...                ...                    ...
# 356022      1491244499   2017-04-03T18:34:59Z
# 356023      1491244499   2017-04-03T18:34:59Z
# 356024      1500730305   2017-07-22T13:31:45Z
# 356025      1492340089   2017-04-16T10:54:49Z
# 356026      1491244499   2017-04-03T18:34:59Z
#
#                                              product_name  \
# 0                                      Farine de blé noir
# 1                          Banana Chips Sweetened (Whole)
# 2                                                 Peanuts
# 3                                  Organic Salted Nut Mix
# 4                                         Organic Polenta
# ...                                                   ...
# 356022  Mint Melange Tea A Blend Of Peppermint, Lemon ...
# 356023                                            乐吧泡菜味薯片
# 356024                                      Biscottes bio
# 356025                           Tomates aux Vermicelles
# 356026                    Sugar Free Drink Mix, Peach Tea
#
#                            generic_name quantity  ...  \
# 0                                   NaN      1kg  ...
# 1                                   NaN      NaN  ...
# 2                                   NaN      NaN  ...
# 3                                   NaN      NaN  ...
# 4                                   NaN      NaN  ...
# ...                                 ...      ...  ...
# 356022                              NaN      NaN  ...
# 356023  Leba pickle flavor potato chips     50 g  ...
# 356024                              NaN     300g  ...
# 356025                              NaN      67g  ...
# 356026                              NaN      NaN  ...
#
#        fruits-vegetables-nuts_100g fruits-vegetables-nuts-estimate_100g  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
# ...                            ...                                  ...
# 356022                         NaN                                  NaN
# 356023                         NaN                                  NaN
# 356024                         NaN                                  NaN
# 356025                         NaN                                  NaN
# 356026                         NaN                                  NaN
#
#        collagen-meat-protein-ratio_100g cocoa_100g chlorophyl_100g  \
# 0                                   NaN        NaN             NaN
# 1                                   NaN        NaN             NaN
# 2                                   NaN        NaN             NaN
# 3                                   NaN        NaN             NaN
# 4                                   NaN        NaN             NaN
# ...                                 ...        ...             ...
# 356022                              NaN        NaN             NaN
# 356023                              NaN        NaN             NaN
# 356024                              NaN        NaN             NaN
# 356025                              NaN        NaN             NaN
# 356026                              NaN        NaN             NaN
#
#        carbon-footprint_100g nutrition-score-fr_100g nutrition-score-uk_100g  \
# 0                        NaN                     NaN                     NaN
# 1                        NaN                    14.0                    14.0
# 2                        NaN                     0.0                     0.0
# 3                        NaN                    12.0                    12.0
# 4                        NaN                     NaN                     NaN
# ...                      ...                     ...                     ...
# 356022                   NaN                     0.0                     0.0
# 356023                   NaN                     NaN                     NaN
# 356024                   NaN                     NaN                     NaN
# 356025                   NaN                     NaN                     NaN
# 356026                   NaN                     NaN                     NaN
#
#        glycemic-index_100g water-hardness_100g
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ...                    ...                 ...
# 356022                 NaN                 NaN
# 356023                 NaN                 NaN
# 356024                 NaN                 NaN
# 356025                 NaN                 NaN
# 356026                 NaN                 NaN
#
# [356027 rows x 163 columns]

# %%
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %%
food.T
# Out:
#                                                                     0       \
# code                                                                  3087
# url                      http://world-en.openfoodfacts.org/product/0000...
# creator                                         openfoodfacts-contributors
# created_t                                                       1474103866
# created_datetime                                      2016-09-17T09:17:46Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     1       \
# code                                                                  4530
# url                      http://world-en.openfoodfacts.org/product/0000...
# creator                                                    usda-ndb-import
# created_t                                                       1489069957
# created_datetime                                      2017-03-09T14:32:37Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                 14
# nutrition-score-uk_100g                                                 14
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     2       \
# code                                                                  4559
# url                      http://world-en.openfoodfacts.org/product/0000...
# creator                                                    usda-ndb-import
# created_t                                                       1489069957
# created_datetime                                      2017-03-09T14:32:37Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                  0
# nutrition-score-uk_100g                                                  0
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     3       \
# code                                                                 16087
# url                      http://world-en.openfoodfacts.org/product/0000...
# creator                                                    usda-ndb-import
# created_t                                                       1489055731
# created_datetime                                      2017-03-09T10:35:31Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                 12
# nutrition-score-uk_100g                                                 12
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     4       \
# code                                                                 16094
# url                      http://world-en.openfoodfacts.org/product/0000...
# creator                                                    usda-ndb-import
# created_t                                                       1489055653
# created_datetime                                      2017-03-09T10:34:13Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     5       \
# code                                                                 16100
# url                      http://world-en.openfoodfacts.org/product/0000...
# creator                                                    usda-ndb-import
# created_t                                                       1489055651
# created_datetime                                      2017-03-09T10:34:11Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     6       \
# code                                                                 16117
# url                      http://world-en.openfoodfacts.org/product/0000...
# creator                                                    usda-ndb-import
# created_t                                                       1489055730
# created_datetime                                      2017-03-09T10:35:30Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     7       \
# code                                                                 16124
# url                      http://world-en.openfoodfacts.org/product/0000...
# creator                                                    usda-ndb-import
# created_t                                                       1489055711
# created_datetime                                      2017-03-09T10:35:11Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                  7
# nutrition-score-uk_100g                                                  7
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     8       \
# code                                                                 16193
# url                      http://world-en.openfoodfacts.org/product/0000...
# creator                                                    usda-ndb-import
# created_t                                                       1489055651
# created_datetime                                      2017-03-09T10:34:11Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     9       \
# code                                                                 16513
# url                      http://world-en.openfoodfacts.org/product/0000...
# creator                                                    usda-ndb-import
# created_t                                                       1489055654
# created_datetime                                      2017-03-09T10:34:14Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                          ...  \
# code                     ...
# url                      ...
# creator                  ...
# created_t                ...
# created_datetime         ...
# ...                      ...
# carbon-footprint_100g    ...
# nutrition-score-fr_100g  ...
# nutrition-score-uk_100g  ...
# glycemic-index_100g      ...
# water-hardness_100g      ...
#
#                                                                     356017  \
# code                                                              99111250
# url                      http://world-en.openfoodfacts.org/product/9911...
# creator                                                           balooval
# created_t                                                       1367163039
# created_datetime                                      2013-04-28T15:30:39Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     356018  \
# code                                                                  9918
# url                      http://world-en.openfoodfacts.org/product/9918...
# creator                                                         woshilapin
# created_t                                                       1430167954
# created_datetime                                      2015-04-27T20:52:34Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     356019  \
# code                                                         9935010000003
# url                      http://world-en.openfoodfacts.org/product/9935...
# creator                                                           sebleouf
# created_t                                                       1446293229
# created_datetime                                      2015-10-31T12:07:09Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     356020  \
# code                                                              99410148
# url                      http://world-en.openfoodfacts.org/product/9941...
# creator                                                    date-limite-app
# created_t                                                       1463936572
# created_datetime                                      2016-05-22T17:02:52Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     356021  \
# code                                                         9948282780603
# url                      http://world-en.openfoodfacts.org/product/9948...
# creator                                         openfoodfacts-contributors
# created_t                                                       1490631299
# created_datetime                                      2017-03-27T16:14:59Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     356022  \
# code                                                              99567453
# url                      http://world-en.openfoodfacts.org/product/9956...
# creator                                                    usda-ndb-import
# created_t                                                       1489059076
# created_datetime                                      2017-03-09T11:31:16Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                  0
# nutrition-score-uk_100g                                                  0
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     356023  \
# code                                                         9970229501521
# url                      http://world-en.openfoodfacts.org/product/9970...
# creator                                                             tomato
# created_t                                                       1422099377
# created_datetime                                      2015-01-24T11:36:17Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     356024  \
# code                                                         9977471758307
# url                      http://world-en.openfoodfacts.org/product/9977...
# creator                                         openfoodfacts-contributors
# created_t                                                       1497018549
# created_datetime                                      2017-06-09T14:29:09Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     356025  \
# code                                                         9980282863788
# url                      http://world-en.openfoodfacts.org/product/9980...
# creator                                         openfoodfacts-contributors
# created_t                                                       1492340089
# created_datetime                                      2017-04-16T10:54:49Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
#                                                                     356026
# code                                                          999990026839
# url                      http://world-en.openfoodfacts.org/product/9999...
# creator                                                    usda-ndb-import
# created_t                                                       1489072709
# created_datetime                                      2017-03-09T15:18:29Z
# ...                                                                    ...
# carbon-footprint_100g                                                  NaN
# nutrition-score-fr_100g                                                NaN
# nutrition-score-uk_100g                                                NaN
# glycemic-index_100g                                                    NaN
# water-hardness_100g                                                    NaN
#
# [163 rows x 356027 columns]

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 22AE-B4A0
#
#  Directory of C:\Users\li-370\ForkGitW\python-data-analysis\pandas_exercises-master\01_Getting_&_Knowing_Your_Data\World Food Facts
#
# 2019/11/19  15:40    <DIR>          .
# 2019/11/19  15:40    <DIR>          ..
# 2019/11/19  15:21    <DIR>          .ipynb_checkpoints
# 2019/10/14  01:14             3,366 Exercises.ipynb
# 2019/11/19  15:40            78,199 Exercises_with_solutions.ipynb
# 2019/10/14  01:14            16,011 Solutions.ipynb
#                3 File(s)         97,576 bytes
#                3 Dir(s)  17,633,914,880 bytes free

# %%
food.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-2303aa4d0e5a> in <module>
# ----> 1 food.shape()
#
# TypeError: 'tuple' object is not callable

# %%
food.shape
# Out:
# (356027, 163)

# %%
import pandasql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-5cd30a9f4f03> in <module>
# ----> 1 import pandasql
#
# ModuleNotFoundError: No module named 'pandasql'

# %%
import pandasql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-22-5cd30a9f4f03> in <module>
# ----> 1 import pandasql
#
# ModuleNotFoundError: No module named 'pandasql'

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356027 entries, 0 to 356026
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(107), object(56)
# memory usage: 442.8+ MB

# %%
food.describe()
# Out:
#        no_nutriments    additives_n  ingredients_from_palm_oil_n  \
# count            0.0  283867.000000                283867.000000
# mean             NaN       1.876851                     0.023430
# std              NaN       2.501022                     0.153094
# min              NaN       0.000000                     0.000000
# 25%              NaN       0.000000                     0.000000
# 50%              NaN       1.000000                     0.000000
# 75%              NaN       3.000000                     0.000000
# max              NaN      30.000000                     2.000000
#
#        ingredients_from_palm_oil  ingredients_that_may_be_from_palm_oil_n  \
# count                        0.0                            283867.000000
# mean                         NaN                                 0.059736
# std                          NaN                                 0.280660
# min                          NaN                                 0.000000
# 25%                          NaN                                 0.000000
# 50%                          NaN                                 0.000000
# 75%                          NaN                                 0.000000
# max                          NaN                                 6.000000
#
#        ingredients_that_may_be_from_palm_oil  nutrition_grade_uk  \
# count                                    0.0                 0.0
# mean                                     NaN                 NaN
# std                                      NaN                 NaN
# min                                      NaN                 NaN
# 25%                                      NaN                 NaN
# 50%                                      NaN                 NaN
# 75%                                      NaN                 NaN
# max                                      NaN                 NaN
#
#          energy_100g  energy-from-fat_100g      fat_100g  ...  \
# count  295367.000000            869.000000  2.794970e+05  ...
# mean     1125.453320            587.216617  5.606587e+04  ...
# std       936.825952            713.255708  2.963385e+07  ...
# min         0.000000              0.000000  0.000000e+00  ...
# 25%       382.000000             49.400000  1.000000e-01  ...
# 50%      1092.000000            300.000000  5.290000e+00  ...
# 75%      1674.000000            900.000000  2.000000e+01  ...
# max    231199.000000           3830.000000  1.566667e+10  ...
#
#        fruits-vegetables-nuts_100g  fruits-vegetables-nuts-estimate_100g  \
# count                  3228.000000                            404.000000
# mean                     33.392680                             60.360124
# std                      32.906834                             29.262350
# min                       0.000000                              0.000000
# 25%                       0.000000                             45.000000
# 50%                      25.000000                             58.000000
# 75%                      55.000000                             93.000000
# max                     100.000000                            100.000000
#
#        collagen-meat-protein-ratio_100g   cocoa_100g  chlorophyl_100g  \
# count                        182.000000  1383.000000              0.0
# mean                          15.362637    52.102675              NaN
# std                            3.692658    19.028361              NaN
# min                            8.000000     6.000000              NaN
# 25%                           12.000000    33.000000              NaN
# 50%                           15.000000    52.000000              NaN
# 75%                           15.000000    70.000000              NaN
# max                           25.000000   100.000000              NaN
#
#        carbon-footprint_100g  nutrition-score-fr_100g  \
# count             278.000000            254856.000000
# mean              335.790664                 9.166137
# std               423.244817                 8.999870
# min                 0.000000               -15.000000
# 25%                82.650000                 1.000000
# 50%               190.950000                10.000000
# 75%               378.700000                16.000000
# max              2842.000000                40.000000
#
#        nutrition-score-uk_100g  glycemic-index_100g  water-hardness_100g
# count            254856.000000                  0.0                  0.0
# mean                  8.980656                  NaN                  NaN
# std                   9.151757                  NaN                  NaN
# min                 -15.000000                  NaN                  NaN
# 25%                   1.000000                  NaN                  NaN
# 50%                   9.000000                  NaN                  NaN
# 75%                  16.000000                  NaN                  NaN
# max                  40.000000                  NaN                  NaN
#
# [8 rows x 107 columns]
